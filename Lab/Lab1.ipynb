# %% [markdown]
# # Лабораторная работа №1
# ## Выполнил студент группы БФИ2001 Ковачев Виктор

# %% [markdown]
# ### Оглавление
# 1. [Задание 1](#Задание-№1)
# 2. [Задание 2](#Задание-№2)
# 3. [Задание 3](#Задание-№3)
# 4. [Вывод](#Вывод)

# %% [markdown]
# ### Задание №1
# <i> Вызвать функцию print() и передать туда строку Hello, World! </i>

# %%
print('Hello, World!')
# Out:
# Hello, World!

# %% [markdown]
# ### Задание №2
# Написать генератор случайных матриц(многомерных), который принимает
# опциональные параметры <b>m</b>, <b>n</b>, <b>min_limit</b>, <b>max_limit</b>, где <b>m</b> и <b>n</b> указывают размер
# матрицы, а <b>min_lim</b> и <b>max_lim</b> - минимальное и максимальное значение для
# генерируемого числа.

# %%
import random
import time
user_m,user_n,user_min_limit,user_max_limit = int(input()),int(input()),int(input()),int(input())
Matrix = [ [ random.randint(user_min_limit, user_max_limit) for j in range(user_n)] for i in range(user_m) ]
print('Matrix:',Matrix)
# Out:
# 5
# 4
# 343
# 12312321
# Matrix: [[4819217, 4520175, 9098617, 10902739], [6772387, 1691978, 3187626, 10000675], [8414856, 9079048, 1827453, 10349513], [5192496, 6383100, 370142, 7338818], [2510313, 1108596, 972939, 10466267]]

# %% [markdown]
# ### Задание №3
# Реализовать методы сортировки строк числовой матрицы в соответствии с
# заданием. Оценить время работы каждого алгоритма сортировки и сравнить его со
# временем стандартной функции сортировки. Испытания проводить на сгенерированных
# матрицах.

# %%
import copy

# %%
def matrix_gen(n,min_limit,max_limit):
    return [ random.randint(min_limit, max_limit) for j in range(n)]

# %%
# Сортировка выбором.
# Берётся срез массива, в котором минимальный элемент переносят в самый левый угол,
# после чего срез уменьшается и цикл повторяется.
start_time = time.time()
mas=matrix_gen(200,-250,1000)
print('Source array:\n',*mas)
def vibor(mas):
    for i in range(len(mas) - 1):
        m = i
        j = i + 1
        while j < len(mas):
            if mas[j] < mas[m]:
                m = j
            j = j + 1
        mas[i], mas[m] = mas[m], mas[i]
    return mas
print ('Sorted matrix:\n',*vibor(mas))
print("--- {0} ms ---".format(round((time.time() - start_time)*1000)))
# Out:
# Source array:
#  653 495 445 313 850 -108 899 542 -142 -205 178 430 935 993 -241 883 26 259 520 968 241 96 -151 221 870 925 400 176 103 69 -103 -74 641 660 270 826 561 602 354 182 -89 140 -157 528 720 122 975 951 421 634 137 320 -132 -3 669 -220 35 724 -132 514 462 620 140 396 612 209 -249 647 526 163 536 15 -162 894 777 222 349 500 857 719 849 910 106 -41 824 -103 571 -118 587 5 867 -182 171 112 350 514 415 -58 259 796 119 941 158 922 815 727 175 72 372 240 465 -235 828 465 525 79 405 474 413 171 -139 964 566 206 -238 357 390 319 476 185 57 -83 231 201 923 -15 874 626 45 843 807 206 70 533 774 883 -71 45 638 -167 360 960 -55 236 712 873 -29 885 516 32 788 586 592 294 820 391 -4 586 -175 31 540 860 244 254 839 -41 -64 -187 -133 89 709 613 76 838 231 49 -191 -115 872 192 503 460 224 -99 -161 251 180 93 587 615
# Sorted matrix:
#  -249 -241 -238 -235 -220 -205 -191 -187 -182 -175 -167 -162 -161 -157 -151 -142 -139 -133 -132 -132 -118 -115 -108 -103 -103 -99 -89 -83 -74 -71 -64 -58 -55 -41 -41 -29 -15 -4 -3 5 15 26 31 32 35 45 45 49 57 69 70 72 76 79 89 93 96 103 106 112 119 122 137 140 140 158 163 171 171 175 176 178 180 182 185 192 201 206 206 209 221 222 224 231 231 236 240 241 244 251 254 259 259 270 294 313 319 320 349 350 354 357 360 372 390 391 396 400 405 413 415 421 430 445 460 462 465 465 474 476 495 500 503 514 514 516 520 525 526 528 533 536 540 542 561 566 571 586 586 587 587 592 602 612 613 615 620 626 634 638 641 647 653 660 669 709 712 719 720 724 727 774 777 788 796 807 815 820 824 826 828 838 839 843 849 850 857 860 867 870 872 873 874 883 883 885 894 899 910 922 923 925 935 941 951 960 964 968 975 993
# --- 9 ms ---

# %%
# Сортировка вставкой.
start_time = time.time()
mas=matrix_gen(200,-250,1000)
print('Source array:\n',*mas)
def vst(mas):
    for i in range(1, len(mas)): 
        value = mas[i] 
        j = i - 1 
        while j >= 0 and value < mas[j]: 
            mas[j + 1] = mas[j] 
            j -= 1 
        mas[j + 1] = value 
    return mas
print ('Sorted matrix:\n',*vst(mas))
print("--- {0} ms ---".format(round((time.time() - start_time)*1000)))
# Out:
# Source array:
#  798 30 731 929 956 512 920 243 -125 345 -37 145 988 117 770 851 48 916 59 -87 325 174 970 518 902 -107 936 904 692 -70 953 -30 300 907 565 206 565 362 -159 183 213 483 986 807 494 54 580 680 904 975 608 996 -110 139 894 439 676 -198 179 386 -239 -79 613 785 394 205 933 253 239 267 968 -159 288 138 185 379 829 348 18 -66 498 607 984 -148 628 341 772 388 263 187 99 36 761 594 113 443 -155 731 -206 816 330 714 596 557 -145 965 396 336 916 612 745 -84 363 543 -50 300 905 834 167 153 611 100 915 973 187 313 549 260 -74 699 863 812 351 924 627 30 442 355 416 233 551 946 556 -62 453 801 -159 423 735 -119 704 59 934 747 -50 897 138 526 -198 402 756 247 291 596 67 -51 650 68 457 600 640 896 421 213 925 -220 195 949 -108 249 137 462 747 830 505 968 126 43 73 53 826 -171 29 86 87 304 -72 94 178 -20
# Sorted matrix:
#  -239 -220 -206 -198 -198 -171 -159 -159 -159 -155 -148 -145 -125 -119 -110 -108 -107 -87 -84 -79 -74 -72 -70 -66 -62 -51 -50 -50 -37 -30 -20 18 29 30 30 36 43 48 53 54 59 59 67 68 73 86 87 94 99 100 113 117 126 137 138 138 139 145 153 167 174 178 179 183 185 187 187 195 205 206 213 213 233 239 243 247 249 253 260 263 267 288 291 300 300 304 313 325 330 336 341 345 348 351 355 362 363 379 386 388 394 396 402 416 421 423 439 442 443 453 457 462 483 494 498 505 512 518 526 543 549 551 556 557 565 565 580 594 596 596 600 607 608 611 612 613 627 628 640 650 676 680 692 699 704 714 731 731 735 745 747 747 756 761 770 772 785 798 801 807 812 816 826 829 830 834 851 863 894 896 897 902 904 904 905 907 915 916 916 920 924 925 929 933 934 936 946 949 953 956 965 968 968 970 973 975 984 986 988 996
# --- 6 ms ---

# %%
# Сортировка обменом. || Сортировка пузырьком.
start_time = time.time()
mas=matrix_gen(200,-250,1000)
print('Source array:\n',*mas)
def obmen(mas):
    swap=True
    while swap:
        swap = False
        for i in range(len(mas) - 1):
            if mas[i] > mas[i + 1]:
                mas[i], mas[i + 1] = mas[i + 1], mas[i]
                swap = True
    return mas
print ('Sorted matrix:\n',*obmen(mas))
print("--- {0} ms ---".format(round((time.time() - start_time)*1000)))
# Out:
# Source array:
#  408 512 -31 553 698 -182 258 991 778 656 -243 263 608 394 708 792 311 -94 764 -70 108 -44 799 88 116 253 967 -71 890 376 411 236 723 522 -24 618 66 -246 565 111 611 -20 -144 433 556 430 320 248 206 333 75 881 132 574 -235 -110 988 983 -87 459 298 -242 692 -176 817 613 146 329 826 95 418 753 880 357 -232 814 192 735 819 86 757 -98 553 370 777 802 415 83 391 -217 994 217 -28 -243 579 729 78 261 840 480 457 634 235 327 207 -198 263 161 444 -80 383 716 807 -219 437 529 -163 27 -178 -115 -247 384 786 156 -142 149 445 915 600 123 871 846 746 -44 8 92 386 221 561 144 -28 829 215 -67 917 109 199 499 584 993 991 159 586 181 913 610 -113 765 595 369 645 -93 1 -138 114 378 185 487 719 338 -132 730 -236 733 542 -208 -3 433 -109 470 794 250 -125 -230 -86 762 467 609 -197 -73 197 576 24 498 163 598 914 -234 299 319
# Sorted matrix:
#  -247 -246 -243 -243 -242 -236 -235 -234 -232 -230 -219 -217 -208 -198 -197 -182 -178 -176 -163 -144 -142 -138 -132 -125 -115 -113 -110 -109 -98 -94 -93 -87 -86 -80 -73 -71 -70 -67 -44 -44 -31 -28 -28 -24 -20 -3 1 8 24 27 66 75 78 83 86 88 92 95 108 109 111 114 116 123 132 144 146 149 156 159 161 163 181 185 192 197 199 206 207 215 217 221 235 236 248 250 253 258 261 263 263 298 299 311 319 320 327 329 333 338 357 369 370 376 378 383 384 386 391 394 408 411 415 418 430 433 433 437 444 445 457 459 467 470 480 487 498 499 512 522 529 542 553 553 556 561 565 574 576 579 584 586 595 598 600 608 609 610 611 613 618 634 645 656 692 698 708 716 719 723 729 730 733 735 746 753 757 762 764 765 777 778 786 792 794 799 802 807 814 817 819 826 829 840 846 871 880 881 890 913 914 915 917 967 983 988 991 991 993 994
# --- 9 ms ---

# %%
# Сортировка Шелла.
start_time = time.time()
mas=matrix_gen(200,-250,1000)
print('Source array:\n',*mas)
def shel(mas):
    inc = len(mas) // 2
    while inc:
        for i, n in enumerate(mas):
            while i >= inc and mas[i - inc] > n:
                mas[i] = mas[i - inc]
                i -= inc
            mas[i] = n
        inc = 1 if inc == 2 else int(inc * 5.0 / 11)
    return mas
print ('Sorted matrix:\n',*shel(mas))
print("--- {0} ms ---".format(round((time.time() - start_time)*1000)))
# Out:
# Source array:
#  -67 885 640 528 427 774 834 119 323 803 -177 572 706 134 704 567 49 64 788 423 894 662 465 909 645 629 59 954 642 865 41 -65 246 765 384 206 187 442 162 -187 810 417 36 352 819 -79 859 506 -180 372 120 320 881 335 -65 983 95 56 384 91 -59 397 -138 935 773 851 583 977 -16 56 673 872 173 611 852 962 301 803 457 -24 170 544 -133 55 602 -235 948 709 345 -233 -70 576 552 994 443 572 -214 -175 85 473 -210 831 718 191 267 44 687 439 705 719 881 915 766 -28 478 279 504 216 -84 346 340 672 -231 839 381 -82 29 557 514 154 -109 670 612 819 350 -132 435 986 635 -196 501 359 -63 608 204 371 327 -116 -149 996 751 576 -159 -22 -134 -163 -17 -4 561 -34 935 870 728 670 31 553 835 73 819 132 527 -163 -4 682 264 107 167 10 627 288 546 151 108 608 -5 786 713 204 -116 198 879 471 294 444 -103 205 737 998 -173 309
# Sorted matrix:
#  -235 -233 -231 -214 -210 -196 -187 -180 -177 -175 -173 -163 -163 -159 -149 -138 -134 -133 -132 -116 -116 -109 -103 -84 -82 -79 -70 -67 -65 -65 -63 -59 -34 -28 -24 -22 -17 -16 -5 -4 -4 10 29 31 36 41 44 49 55 56 56 59 64 73 85 91 95 107 108 119 120 132 134 151 154 162 167 170 173 187 191 198 204 204 205 206 216 246 264 267 279 288 294 301 309 320 323 327 335 340 345 346 350 352 359 371 372 381 384 384 397 417 423 427 435 439 442 443 444 457 465 471 473 478 501 504 506 514 527 528 544 546 552 553 557 561 567 572 572 576 576 583 602 608 608 611 612 627 629 635 640 642 645 662 670 670 672 673 682 687 704 705 706 709 713 718 719 728 737 751 765 766 773 774 786 788 803 803 810 819 819 819 831 834 835 839 851 852 859 865 870 872 879 881 881 885 894 909 915 935 935 948 954 962 977 983 986 994 996 998
# --- 5 ms ---

# %%
# Быстрая сортировка.
start_time = time.time()
mas=matrix_gen(200,-250,1000)
print('Source array:\n',*mas)
def quicksort(mas):
    if len(mas) <= 1:
        return mas
    else:
        q = random.choice(mas)
    a_mas = [n for n in mas if n < q]
 
    r_mas = [q] * mas.count(q)
    b_mas = [n for n in mas if n > q]
    return quicksort(a_mas) + r_mas + quicksort(b_mas)
print ('Sorted matrix:\n',*quicksort(mas))
print("--- {0} ms ---".format(round((time.time() - start_time)*1000)))
# Out:
# Source array:
#  396 265 195 684 212 26 -233 511 -32 -39 359 -121 154 204 200 137 -110 -79 265 673 -18 993 -236 999 488 30 887 400 -146 838 698 499 240 834 -246 24 -46 16 76 285 -122 362 138 249 666 583 120 54 445 650 595 -98 -203 837 831 902 95 956 354 475 303 582 -25 599 256 602 745 562 283 344 801 714 912 737 618 -210 -32 678 -123 802 959 120 166 306 122 418 177 855 -138 76 348 923 418 409 327 543 -236 -211 138 716 913 222 699 7 -149 159 -44 494 797 374 300 -219 3 311 884 420 479 72 930 867 554 92 -209 43 808 626 166 605 264 67 965 111 376 966 92 970 -185 -229 503 -52 414 363 332 657 -57 758 215 897 70 195 256 297 272 201 442 182 483 -122 198 412 442 994 -224 266 357 943 33 190 772 -187 -73 80 879 124 285 711 702 431 295 -82 403 -176 359 686 75 460 236 850 755 993 882 887 119 -50 364 762 719 -3 -8 482
# Sorted matrix:
#  -246 -236 -236 -233 -229 -224 -219 -211 -210 -209 -203 -187 -185 -176 -149 -146 -138 -123 -122 -122 -121 -110 -98 -82 -79 -73 -57 -52 -50 -46 -44 -39 -32 -32 -25 -18 -8 -3 3 7 16 24 26 30 33 43 54 67 70 72 75 76 76 80 92 92 95 111 119 120 120 122 124 137 138 138 154 159 166 166 177 182 190 195 195 198 200 201 204 212 215 222 236 240 249 256 256 264 265 265 266 272 283 285 285 295 297 300 303 306 311 327 332 344 348 354 357 359 359 362 363 364 374 376 396 400 403 409 412 414 418 418 420 431 442 442 445 460 475 479 482 483 488 494 499 503 511 543 554 562 582 583 595 599 602 605 618 626 650 657 666 673 678 684 686 698 699 702 711 714 716 719 737 745 755 758 762 772 797 801 802 808 831 834 837 838 850 855 867 879 882 884 887 887 897 902 912 913 923 930 943 956 959 965 966 970 993 993 994 999
# --- 6 ms ---

# %%
# Турнирная сортировка.
import heapq
start_time = time.time()
list_n=matrix_gen(200,-200,1000)
print('Source array:\n',*mas)
def turnir(mas):
    size=len(mas)
    max_s=len(mas)+1
    h=[]
    while len(h)<max_s and len(mas)>0:
        heapq.heappush(h,mas.pop(0))
    win=[]
    los=[]
    while len(mas)>0:
        if len(win)==0:
            win.append(heapq.heappop(h))
        if mas[0]>win[-1]:
            heapq.heappush(h,mas.pop(0))
        else:
            los.append(mas.pop(0))
                    
            if len(h)>0:
                win.append(heapq.heappop(h))
    while len(h)>0:
        win.append(heapq.heappop(h))
    if len(los)==0:
        return win
    los=turnir(los)
    def merge(mas_a,mas_b,res):
        a,b,r=0,0,0
        while a<len(mas_a) and b<len(mas_b):
            if mas_a[a]<mas_b[b]:
                res[r]=mas_a[a]
                a+=1
            else:
                res[r]==mas_b[b]
                b+=1
            r+=1
        while a<len(mas_a):
            res[r]==mas_a[a]
            a+=1
            r+=1
        while b<len(mas_b):
            res[r]=mas_b[b]
            b+=1
            r+=1
                
    mas=list(range(size))
    merge(los,win,mas)
    return mas  
    
print ('Sorted matrix:\n',*turnir(list_n))
print("--- {0} ms ---".format(round((time.time() - start_time)*1000)))
# Out:
# Source array:
#  396 265 195 684 212 26 -233 511 -32 -39 359 -121 154 204 200 137 -110 -79 265 673 -18 993 -236 999 488 30 887 400 -146 838 698 499 240 834 -246 24 -46 16 76 285 -122 362 138 249 666 583 120 54 445 650 595 -98 -203 837 831 902 95 956 354 475 303 582 -25 599 256 602 745 562 283 344 801 714 912 737 618 -210 -32 678 -123 802 959 120 166 306 122 418 177 855 -138 76 348 923 418 409 327 543 -236 -211 138 716 913 222 699 7 -149 159 -44 494 797 374 300 -219 3 311 884 420 479 72 930 867 554 92 -209 43 808 626 166 605 264 67 965 111 376 966 92 970 -185 -229 503 -52 414 363 332 657 -57 758 215 897 70 195 256 297 272 201 442 182 483 -122 198 412 442 994 -224 266 357 943 33 190 772 -187 -73 80 879 124 285 711 702 431 295 -82 403 -176 359 686 75 460 236 850 755 993 882 887 119 -50 364 762 719 -3 -8 482
# Sorted matrix:
#  -200 -194 -192 -192 -190 -189 -180 -176 -175 -170 -169 -169 -142 -139 -129 -127 -127 -119 -117 -115 -111 -103 -100 -96 -95 -92 -85 -72 -59 -56 -53 -35 -33 -33 -32 -16 8 17 18 27 29 32 40 43 49 50 51 85 99 118 122 122 126 131 141 143 147 159 159 162 166 167 167 178 179 183 184 194 209 210 216 232 234 246 265 273 276 285 293 298 299 306 311 311 325 327 328 331 337 341 344 345 380 387 388 392 394 395 397 401 405 414 434 438 440 442 448 460 461 462 465 471 478 486 489 496 498 500 501 508 509 510 511 511 525 527 534 537 546 558 564 574 575 581 584 584 587 589 610 626 628 629 633 642 649 653 665 667 669 674 686 699 699 703 713 716 720 726 732 748 756 763 770 770 785 785 786 789 789 790 811 816 821 839 840 855 886 887 895 899 903 911 912 914 915 915 919 922 925 927 933 934 945 946 958 960 961 968 970 984
# --- 5 ms ---

# %% [markdown]
# ### Вывод
